# %%
import re
import difflib

def get_words(filename):
     
    with open(filename, encoding="utf8") as file:
        text = file.read()
    
    text = re.sub('[^\w]', ' ', text).lower()
    words = text.split()
    return words
 
def get_words_dict(words):
    words_dict = dict()
 
    for word in words:
        if len(word) <= 2 : continue
        if word in words_dict:
            words_dict[word] = words_dict[word] + 1
        else:
            words_dict[word] = 1
    return sorted(words_dict.items(), key=lambda x: len(x[0]))

def fold_words(words_dict):
    new_dict = dict()
    
    for word, number in words_dict:
        new_dict = add_item(word, number, new_dict)
    return new_dict

def similarity(a, b):
  matcher = difflib.SequenceMatcher(None, a, b)
  return matcher.ratio()

def add_item(word, number, new_dict):
    add = True
    for old_word in list(new_dict):
        #if word in new_dict : continue
        test = similarity(old_word, word) 
        #test =1
        is_close = distance(old_word, word)
        if  (is_close and test >= 0.8) and add:
            new_dict[old_word]['count'] += number
            new_dict[old_word]['list'].append(word)
            add = False
    if add: new_dict[word] = {'count': number, 'list': [word]}
        
    return new_dict

def distance(a, b):
    "Calculates the Levenshtein distance between a and b."
    n, m = len(a), len(b)
    if n > m:
        a, b = b, a
        n, m = m, n

    current_row = range(n+1) 
    for i in range(1, m+1):
        previous_row, current_row = current_row, [i]+[0]*n
        for j in range(1,n+1):
            #изменен вес на удаление
            add, delete, change = previous_row[j]+1, current_row[j-1]+2, previous_row[j-1]
            if a[j-1] != b[i-1]:
                change += 1
            current_row[j] = min(add, delete, change)
    return (m/2)>current_row[n] and n != m
    
 
 
def main(filename):
    words = get_words(filename)
    words_dict = get_words_dict(words)
    words_dict = fold_words(words_dict)
    print("Кол-во слов: %d" % len(words))
    print("Кол-во уникальных слов: %d" % len(words_dict))
    print("Все использованные слова:")
    for word in sorted(words_dict.items(), key=lambda i: i[1]["count"], reverse=True):
         print(word)
            
main('Data/mytext.txt')
# Out:
# Кол-во слов: 22882
# Кол-во уникальных слов: 3045
# Все использованные слова:
# ('что', {'count': 438, 'list': ['что', 'чтоб']})
# ('сказал', {'count': 381, 'list': ['сказал', 'сказала', 'сказали']})
# ('был', {'count': 297, 'list': ['был', 'была', 'были', 'было']})
# ('его', {'count': 294, 'list': ['его', 'него', 'чего']})
# ('гуннар', {'count': 275, 'list': ['гуннар', 'гуннару', 'гуннара', 'гуннаре', 'гуннаров', 'гуннаром']})
# ('хрут', {'count': 232, 'list': ['хрут', 'хрута', 'хруте', 'хруту', 'хрутом', 'хрутов']})
# ('они', {'count': 218, 'list': ['они', 'одни']})
# ('она', {'count': 204, 'list': ['она']})
# ('это', {'count': 200, 'list': ['это', 'этой', 'этом', 'этот']})
# ('все', {'count': 172, 'list': ['все', 'всем', 'всех', 'всей']})
# ('ему', {'count': 139, 'list': ['ему', 'нему', 'чему']})
# ('хёскульд', {'count': 123, 'list': ['хёскульд', 'хёскульда', 'хёскульду', 'хёскульдов', 'хёскульдом', 'хёскульдова', 'хёскульдовом']})
# ('халльгерд', {'count': 121, 'list': ['халльгерд', 'халлльгерд']})
# ('просил', {'count': 113, 'list': ['просил', 'спросил', 'попросил', 'спросила', 'спросили', 'попросили', 'запросили', 'просидели', 'попросила']})
# ('говорит', {'count': 111, 'list': ['говорит', 'говоришь', 'повторит', 'говорила', 'говорить', 'говорили', 'говорится', 'говориться', 'договорить', 'заговорите', 'поговорить']})
# ('как', {'count': 105, 'list': ['как']})
# ('тебе', {'count': 99, 'list': ['тебе']})
# ('ньяль', {'count': 97, 'list': ['ньяль']})
# ('человек', {'count': 92, 'list': ['человек', 'человека', 'человеке', 'человеку', 'человеком']})
# ('если', {'count': 92, 'list': ['если', 'унесли']})
# ('там', {'count': 90, 'list': ['там']})
# ('тебя', {'count': 85, 'list': ['тебя']})
# ('мне', {'count': 85, 'list': ['мне']})
# ('так', {'count': 84, 'list': ['так', 'таки']})
# ('тот', {'count': 80, 'list': ['тот', 'тоти']})
# ('затем', {'count': 79, 'list': ['затем']})
# ('ехал', {'count': 79, 'list': ['ехал', 'уехал', 'ехали', 'уехали', 'поехал', 'уехала', 'выехал']})
# ('чтобы', {'count': 74, 'list': ['чтобы']})
# ('ним', {'count': 73, 'list': ['ним', 'ними']})
# ('друг', {'count': 72, 'list': ['друг', 'друга', 'другу', 'вдруг', 'других', 'другое', 'другим', 'другом', 'другой', 'другую', 'другие']})
# ('ответ', {'count': 69, 'list': ['ответ', 'ответа', 'отвести', 'отведут', 'ответит', 'ответил', 'ответив']})
# ('тогда', {'count': 69, 'list': ['тогда']})
# ('когда', {'count': 68, 'list': ['когда', 'никогда']})
# ('хорош', {'count': 66, 'list': ['хорош', 'хорошо', 'хороша', 'хороши', 'хороших', 'хорошей', 'хорошая', 'хороший', 'хорошим', 'хорошее', 'хорошие']})
# ('дом', {'count': 66, 'list': ['дом', 'дома', 'доме', 'дому']})
# ('тьостольв', {'count': 65, 'list': ['тьостольв', 'тьостольву', 'тьостольва', 'тьостольвом']})
# ('того', {'count': 65, 'list': ['того', 'этого', 'пятого', 'тощего']})
# ('сын', {'count': 63, 'list': ['сын', 'сыну', 'сына']})
# ('рассказ', {'count': 62, 'list': ['рассказ', 'расскажи', 'рассекла', 'рассказав', 'рассказал', 'рассказали', 'рассказала', 'рассказать']})
# ('тинг', {'count': 62, 'list': ['тинг', 'тинга', 'тинге']})
# ('меня', {'count': 61, 'list': ['меня', 'менять']})
# ('брат', {'count': 61, 'list': ['брат', 'брата', 'брать', 'брату', 'убрать', 'братья', 'братом']})
# ('будет', {'count': 58, 'list': ['будет', 'будете']})
# ('домой', {'count': 56, 'list': ['домой']})
# ('потом', {'count': 54, 'list': ['потом', 'потому']})
# ('глум', {'count': 52, 'list': ['глум', 'глуму', 'глума', 'глумом', 'глупым']})
# ('свое', {'count': 52, 'list': ['свое', 'своем', 'своей', 'своему', 'своего']})
# ('очень', {'count': 50, 'list': ['очень']})
# ('двор', {'count': 49, 'list': ['двор', 'двору', 'дворе', 'двора', 'двором', 'дворам']})
# ('мёрд', {'count': 49, 'list': ['мёрд', 'мёрду', 'мёрда', 'мёрдом']})
# ('люди', {'count': 49, 'list': ['люди', 'людьми']})
# ('поехали', {'count': 49, 'list': ['поехали', 'подыхали', 'похвалил', 'приехали']})
# ('атли', {'count': 48, 'list': ['атли']})
# ('конунг', {'count': 46, 'list': ['конунг', 'конунге', 'конунгу', 'конунга', 'конунги', 'конунгом']})
# ('много', {'count': 45, 'list': ['много', 'умного', 'многое', 'немного']})
# ('больше', {'count': 45, 'list': ['больше', 'большие', 'большое', 'побольше']})
# ('дело', {'count': 45, 'list': ['дело', 'делом']})
# ('мой', {'count': 45, 'list': ['мой', 'мной', 'моей']})
# ('людей', {'count': 44, 'list': ['людей']})
# ('сигмунд', {'count': 43, 'list': ['сигмунд', 'сигмунда', 'сигмунду', 'сигмундом']})
# ('еще', {'count': 43, 'list': ['еще']})
# ('чем', {'count': 42, 'list': ['чем']})
# ('свои', {'count': 42, 'list': ['свои', 'своим', 'своих', 'своими', 'сводил']})
# ('хочу', {'count': 42, 'list': ['хочу']})
# ('раз', {'count': 41, 'list': ['раз', 'раза', 'разу']})
# ('них', {'count': 40, 'list': ['них']})
# ('траин', {'count': 40, 'list': ['траин', 'траином', 'торарин']})
# ('теперь', {'count': 39, 'list': ['теперь']})
# ('дочь', {'count': 37, 'list': ['дочь']})
# ('ньяля', {'count': 37, 'list': ['ньяля']})
# ('рук', {'count': 37, 'list': ['рук', 'руки', 'рука', 'руке', 'руку']})
# ('ста', {'count': 35, 'list': ['ста', 'стал', 'стар']})
# ('только', {'count': 34, 'list': ['только', 'столько', 'настолько']})
# ('дела', {'count': 34, 'list': ['дела', 'делам', 'делах', 'делай', 'делал', 'делали', 'сделай', 'делают', 'сделаю', 'сделал']})
# ('торвальд', {'count': 34, 'list': ['торвальд', 'торвальду', 'торвальда', 'торвальдом']})
# ('том', {'count': 34, 'list': ['том', 'тому']})
# ('фьорд', {'count': 33, 'list': ['фьорд', 'фьорда', 'фьорды', 'фьорде', 'фьорду', 'фьордам', 'фьордов']})
# ('остался', {'count': 33, 'list': ['остался', 'остается', 'осталось', 'остаться', 'осталась', 'старался', 'остались', 'останься', 'оставался', 'посватался']})
# ('взял', {'count': 33, 'list': ['взял', 'взяла', 'взяли', 'взялся']})
# ('жил', {'count': 33, 'list': ['жил', 'жили']})
# ('поле', {'count': 33, 'list': ['поле', 'подле', 'после', 'пошлет', 'вполне']})
# ('звали', {'count': 33, 'list': ['звали', 'вызвали', 'завалил', 'назвали']})
# ('кто', {'count': 33, 'list': ['кто']})
# ('скарпхедин', {'count': 33, 'list': ['скарпхедин']})
# ('путь', {'count': 33, 'list': ['путь', 'пусть']})
# ('собой', {'count': 32, 'list': ['собой']})
# ('торд', {'count': 32, 'list': ['торд', 'торда', 'торду', 'тордом']})
# ('нет', {'count': 32, 'list': ['нет']})
# ('ехать', {'count': 32, 'list': ['ехать', 'уехать', 'выехать', 'поехать']})
# ('над', {'count': 31, 'list': ['над', 'надо']})
# ('день', {'count': 31, 'list': ['день', 'деньги']})
# ('вот', {'count': 30, 'list': ['вот']})
# ('сыновья', {'count': 30, 'list': ['сыновья', 'сыновьям', 'сыновьях', 'сыновьями']})
# ('имени', {'count': 30, 'list': ['имени']})
# ('удар', {'count': 30, 'list': ['удар', 'удару', 'ударил', 'ударом', 'ударив']})
# ('дать', {'count': 30, 'list': ['дать', 'ждать', 'давать', 'выдать', 'делать', 'подать']})
# ('рек', {'count': 30, 'list': ['рек', 'реке', 'рекс', 'реки', 'реку']})
# ('между', {'count': 30, 'list': ['между']})
# ('себе', {'count': 29, 'list': ['себе']})
# ('будь', {'count': 29, 'list': ['будь', 'будешь', 'нибудь']})
# ('нам', {'count': 29, 'list': ['нам', 'нами']})
# ('видел', {'count': 29, 'list': ['видел', 'видели', 'увидел', 'увидели', 'увидела']})
# ('родич', {'count': 28, 'list': ['родич', 'родичи', 'родичу', 'родича', 'родичам', 'родичей', 'родичем']})
# ('ней', {'count': 28, 'list': ['ней', 'дней']})
# ('гор', {'count': 27, 'list': ['гор', 'горы', 'горя', 'горе', 'гора', 'гору']})
# ('сам', {'count': 27, 'list': ['сам', 'сами', 'сама']})
# ('пред', {'count': 27, 'list': ['пред', 'перед', 'прежде', 'передо', 'приеду', 'вперед']})
# ('тут', {'count': 27, 'list': ['тут']})
# ('себя', {'count': 26, 'list': ['себя']})
# ('корабль', {'count': 26, 'list': ['корабль']})
# ('для', {'count': 26, 'list': ['для', 'доля']})
# ('тобой', {'count': 26, 'list': ['тобой']})
# ('нас', {'count': 26, 'list': ['нас']})
# ('вернусь', {'count': 26, 'list': ['вернусь', 'вернулся', 'вернулась', 'вернулись', 'вернувшись']})
# ('время', {'count': 26, 'list': ['время']})
# ('пока', {'count': 26, 'list': ['пока', 'покажи', 'покажу']})
# ('долин', {'count': 26, 'list': ['долин', 'долины', 'долине', 'долину']})
# ('вам', {'count': 26, 'list': ['вам', 'вами']})
# ('гуннхильд', {'count': 25, 'list': ['гуннхильд']})
# ('твое', {'count': 25, 'list': ['твое', 'твоем', 'твоей', 'твоему', 'твоего']})
# ('убил', {'count': 25, 'list': ['убил', 'убили', 'рубил']})
# ('месте', {'count': 25, 'list': ['месте', 'вместе']})
# ('здесь', {'count': 25, 'list': ['здесь']})
# ('бергтора', {'count': 25, 'list': ['бергтора', 'бергторова']})
# ('ничего', {'count': 25, 'list': ['ничего']})
# ('мать', {'count': 25, 'list': ['мать', 'мешать']})
# ('освивр', {'count': 24, 'list': ['освивр', 'освивру', 'освивра', 'освивром']})
# ('убийстве', {'count': 24, 'list': ['убийстве']})
# ('хотел', {'count': 24, 'list': ['хотел', 'хотела', 'хотели', 'захотел']})
# ('пошел', {'count': 23, 'list': ['пошел', 'подошел']})
# ('принял', {'count': 23, 'list': ['принял', 'приняла', 'приняли', 'принялись', 'принялась']})
# ('случилось', {'count': 23, 'list': ['случилось', 'получилось']})
# ('склон', {'count': 23, 'list': ['склон', 'склону', 'склоне', 'склона']})
# ('конец', {'count': 23, 'list': ['конец', 'наконец']})
# ('разговор', {'count': 23, 'list': ['разговор', 'разговоре', 'разговоры', 'разговора', 'разговору', 'разговоров']})
# ('знаю', {'count': 23, 'list': ['знаю', 'знают', 'узнают']})
# ('добро', {'count': 22, 'list': ['добро', 'добром', 'доброго', 'доброму']})
# ('пошли', {'count': 22, 'list': ['пошли', 'прошли', 'подошли']})
# ('копье', {'count': 22, 'list': ['копье', 'копьем']})
# ('кого', {'count': 22, 'list': ['кого', 'никого', 'такого', 'какого']})
# ('придет', {'count': 22, 'list': ['придет', 'приедет', 'придется', 'приведет']})
# ('послал', {'count': 22, 'list': ['послал', 'послала', 'послали']})
# ('хочешь', {'count': 22, 'list': ['хочешь']})
# ('уже', {'count': 22, 'list': ['уже', 'хуже']})
# ('эти', {'count': 21, 'list': ['эти', 'этим', 'этих']})
# ('твои', {'count': 21, 'list': ['твои', 'твоим', 'твоих', 'твоими']})
# ('предложи', {'count': 20, 'list': ['предложи', 'предложил', 'предложить', 'предложение', 'предложении']})
# ('хочет', {'count': 20, 'list': ['хочет', 'захочет', 'хочется']})
# ('вас', {'count': 20, 'list': ['вас']})
# ('знал', {'count': 20, 'list': ['знал', 'знали', 'узнал', 'узнали', 'узнала']})
# ('грим', {'count': 20, 'list': ['грим', 'грима', 'гриму', 'асгрим', 'гримом']})
# ('убит', {'count': 20, 'list': ['убит', 'убить', 'рубить', 'убитых', 'убитый']})
# ('совет', {'count': 20, 'list': ['совет', 'совета', 'советы', 'советам', 'советом', 'советов']})
# ('также', {'count': 20, 'list': ['также']})
# ('запад', {'count': 20, 'list': ['запад', 'западе']})
# ('туда', {'count': 20, 'list': ['туда', 'откуда', 'оттуда']})
# ('унн', {'count': 20, 'list': ['унн']})
# ('сидел', {'count': 19, 'list': ['сидел', 'сидели', 'сидела']})
# ('ест', {'count': 19, 'list': ['ест', 'есть', 'мест']})
# ('тем', {'count': 19, 'list': ['тем']})
# ('лучше', {'count': 19, 'list': ['лучше', 'лучшей', 'получше']})
# ('верно', {'count': 19, 'list': ['верно', 'наверно']})
# ('приехал', {'count': 19, 'list': ['приехал']})
# ('одного', {'count': 18, 'list': ['одного', 'родного', 'лодейного']})
# ('виру', {'count': 18, 'list': ['виру']})
# ('сел', {'count': 18, 'list': ['сел', 'смел', 'счел', 'села', 'сели']})
# ('стали', {'count': 18, 'list': ['стали', 'застали']})
# ('буду', {'count': 18, 'list': ['буду', 'будут', 'забуду']})
# ('эцур', {'count': 18, 'list': ['эцур', 'эцура', 'эцуру', 'эцуром']})
# ('другого', {'count': 18, 'list': ['другого']})
# ('поезжай', {'count': 18, 'list': ['поезжай', 'поезжайте']})
# ('брюньольв', {'count': 18, 'list': ['брюньольв', 'брюньольву', 'брюньольва', 'брюньольвом']})
# ('которое', {'count': 18, 'list': ['которое', 'которому', 'которого', 'некоторое']})
# ('ответила', {'count': 17, 'list': ['ответила', 'ответчика']})
# ('отцом', {'count': 17, 'list': ['отцом']})
# ('три', {'count': 17, 'list': ['три']})
# ('женой', {'count': 17, 'list': ['женой', 'женской']})
# ('дал', {'count': 17, 'list': ['дал', 'дали', 'ждал', 'дала']})
# ('собирался', {'count': 17, 'list': ['собирался', 'собираются', 'собирается', 'собираться', 'собираешься']})
# ('жить', {'count': 17, 'list': ['жить', 'пожить', 'нажить']})
# ('соти', {'count': 17, 'list': ['соти', 'сотни', 'смотри']})
# ('ньялю', {'count': 16, 'list': ['ньялю']})
# ('халльвард', {'count': 16, 'list': ['халльвард', 'халльварду', 'халльвардом']})
# ('товар', {'count': 16, 'list': ['товар', 'товары', 'товарах', 'товарищ', 'товаров']})
# ('один', {'count': 16, 'list': ['один']})
# ('ведь', {'count': 16, 'list': ['ведь']})
# ('коня', {'count': 16, 'list': ['коня', 'коням', 'конях']})
# ('корабле', {'count': 16, 'list': ['корабле', 'кораблем', 'кораблях', 'кораблей']})
# ('всю', {'count': 16, 'list': ['всю']})
# ('нужно', {'count': 16, 'list': ['нужно']})
# ('секирой', {'count': 16, 'list': ['секирой', 'секирной']})
# ('сван', {'count': 16, 'list': ['сван', 'свана', 'сваном', 'сванов']})
# ('сразу', {'count': 16, 'list': ['сразу']})
# ('должен', {'count': 16, 'list': ['должен']})
# ('быть', {'count': 16, 'list': ['быть', 'бывать', 'добыть']})
# ('два', {'count': 15, 'list': ['два', 'едва']})
# ('нем', {'count': 15, 'list': ['нем', 'днем']})
# ('сторон', {'count': 15, 'list': ['сторон', 'сторону', 'стороне', 'стороны']})
# ('меч', {'count': 15, 'list': ['меч', 'меча', 'мечу']})
# ('долг', {'count': 15, 'list': ['долг', 'долго', 'долги', 'долгое']})
# ('лес', {'count': 15, 'list': ['лес', 'лесу', 'леса']})
# ('встречи', {'count': 15, 'list': ['встречи', 'встречен', 'встретив', 'встретит', 'встретил']})
# ('бергтору', {'count': 15, 'list': ['бергтору', 'бергторой', 'бергторов']})
# ('корабли', {'count': 15, 'list': ['корабли', 'кораблями']})
# ('женщин', {'count': 15, 'list': ['женщин', 'женщины', 'женщина', 'женщиной', 'женщинами']})
# ('внук', {'count': 15, 'list': ['внук', 'внука', 'внучку', 'внучка', 'внуком']})
# ('оно', {'count': 15, 'list': ['оно', 'одно']})
# ('сигфус', {'count': 15, 'list': ['сигфус', 'сигфуса']})
# ('мое', {'count': 15, 'list': ['мое', 'моем', 'море']})
# ('восток', {'count': 15, 'list': ['восток', 'востоке', 'востока', 'востоку']})
# ('может', {'count': 15, 'list': ['может', 'сможет', 'поможет']})
# ('где', {'count': 15, 'list': ['где']})
# ('коль', {'count': 15, 'list': ['коль', 'кошель', 'кольцо', 'кольца']})
# ('тяжбу', {'count': 15, 'list': ['тяжбу']})
# ('начал', {'count': 15, 'list': ['начал', 'начали', 'начала', 'начале', 'сначала', 'начался']})
# ('тотчас', {'count': 15, 'list': ['тотчас']})
# ('раб', {'count': 14, 'list': ['раб', 'рабы', 'раба']})
# ('без', {'count': 14, 'list': ['без']})
# ('остров', {'count': 14, 'list': ['остров', 'острову', 'острова', 'острове', 'островам', 'островов', 'островом', 'островных', 'островной', 'островком']})
# ('просить', {'count': 14, 'list': ['просить', 'спросить', 'поносить', 'порочить']})
# ('мои', {'count': 14, 'list': ['мои', 'моих', 'моим']})
# ('спрашивает', {'count': 14, 'list': ['спрашивает', 'спрашиваешь']})
# ('при', {'count': 14, 'list': ['при']})
# ('сыном', {'count': 14, 'list': ['сыном']})
# ('наш', {'count': 14, 'list': ['наш', 'нашу', 'наши', 'наше', 'наша']})
# ('богат', {'count': 14, 'list': ['богат', 'богатой', 'богатые', 'богатая', 'богатый', 'богатую']})
# ('кольскегт', {'count': 14, 'list': ['кольскегт', 'кольскеггу', 'кольскегга', 'кольскегта', 'кольскегту', 'кольскегтом', 'кольскеггом']})
# ('щит', {'count': 14, 'list': ['щит', 'щиту', 'щиты']})
# ('суд', {'count': 14, 'list': ['суд', 'суда', 'суду', 'суде', 'судя']})
# ('мало', {'count': 14, 'list': ['мало', 'немало']})
# ('дочери', {'count': 14, 'list': ['дочери']})
# ('оружие', {'count': 14, 'list': ['оружие']})
# ('корабля', {'count': 14, 'list': ['корабля']})
# ('зиму', {'count': 14, 'list': ['зиму']})
# ('отвечай', {'count': 14, 'list': ['отвечай', 'отвечает']})
# ('сговор', {'count': 14, 'list': ['сговор', 'сговоре', 'сговора']})
# ('отец', {'count': 14, 'list': ['отец']})
# ('нрав', {'count': 13, 'list': ['нрав', 'нрава', 'нраве', 'нравом']})
# ('слов', {'count': 13, 'list': ['слов', 'слово', 'слове', 'словно', 'словах']})
# ('коля', {'count': 13, 'list': ['коля', 'колля']})
# ('поднял', {'count': 13, 'list': ['поднял', 'поднялся', 'поднялись']})
# ('направился', {'count': 13, 'list': ['направился', 'направились']})
# ('хельги', {'count': 13, 'list': ['хельги']})
# ('голову', {'count': 13, 'list': ['голову', 'голову3']})
# ('лет', {'count': 13, 'list': ['лет', 'лету', 'лета', 'лето']})
# ('лова', {'count': 13, 'list': ['лова', 'слова', 'голова']})
# ('торгерд', {'count': 13, 'list': ['торгерд']})
# ('стану', {'count': 13, 'list': ['стану', 'станут']})
# ('мог', {'count': 13, 'list': ['мог', 'могу', 'смог']})
# ('кольскегг', {'count': 13, 'list': ['кольскегг']})
# ('эльвир', {'count': 13, 'list': ['эльвир', 'эльвира', 'эльвиру']})
# ('пор', {'count': 13, 'list': ['пор', 'опор', 'поры', 'пору', 'пора']})
# ('плохо', {'count': 13, 'list': ['плохо', 'плохой', 'неплохо']})
# ('оба', {'count': 13, 'list': ['оба']})
# ('убийство', {'count': 12, 'list': ['убийство', 'убийством']})
# ('ульв', {'count': 12, 'list': ['ульв', 'ульва', 'ульвом']})
# ('всего', {'count': 12, 'list': ['всего']})
# ('скьёльд', {'count': 12, 'list': ['скьёльд', 'скьёльда', 'скьёльду']})
# ('схватил', {'count': 12, 'list': ['схватил', 'захватил', 'схватился']})
# ('видно', {'count': 12, 'list': ['видно']})
# ('звался', {'count': 12, 'list': ['звался', 'назвался', 'завязался', 'назывался']})
# ('север', {'count': 12, 'list': ['север', 'севера', 'севере', 'северу']})
# ('назначу', {'count': 12, 'list': ['назначу', 'назначат', 'назначен', 'назначай', 'назначил', 'назначаю']})
# ('поблагодарил', {'count': 12, 'list': ['поблагодарил', 'поблагодарила', 'поблагодарили']})
# ('сообщил', {'count': 12, 'list': ['сообщил', 'сообщить']})
# ('ноги', {'count': 12, 'list': ['ноги', 'ногти', 'многим', 'многих']})
# ('скажешь', {'count': 12, 'list': ['скажешь', 'расскажешь']})
# ('свидетели', {'count': 12, 'list': ['свидетели', 'свидетелей', 'свидетелями']})
# ('выше', {'count': 12, 'list': ['выше', 'вышел']})
# ('объявил', {'count': 12, 'list': ['объявил', 'объявишь', 'объявлен', 'объявляю']})
# ('той', {'count': 12, 'list': ['той', 'твой']})
# ('нее', {'count': 12, 'list': ['нее']})
# ('станет', {'count': 12, 'list': ['станет', 'останется']})
# ('велел', {'count': 12, 'list': ['велел', 'велела']})
# ('год', {'count': 12, 'list': ['год', 'годи', 'года', 'году']})
# ('бою', {'count': 12, 'list': ['бою']})
# ('говорил', {'count': 12, 'list': ['говорил', 'поговорил', 'поговорили', 'заговорили']})
# ('собрали', {'count': 12, 'list': ['собрали', 'собразил', 'собрался', 'собрались']})
# ('встретили', {'count': 11, 'list': ['встретили', 'встретился', 'встретились']})
# ('стать', {'count': 11, 'list': ['стать', 'сватать', 'страсть', 'статься']})
# ('обратился', {'count': 11, 'list': ['обратился', 'обратиться', 'обратилась', 'возвратился']})
# ('кажется', {'count': 11, 'list': ['кажется', 'покажется']})
# ('пир', {'count': 11, 'list': ['пир', 'пиру', 'пира']})
# ('замуж', {'count': 11, 'list': ['замуж', 'замужем']})
# ('вальгард', {'count': 11, 'list': ['вальгард', 'вальгарда']})
# ('сеча', {'count': 11, 'list': ['сеча', 'сейчас']})
# ('ярл', {'count': 11, 'list': ['ярл', 'ярла']})
# ('золото', {'count': 11, 'list': ['золото', 'золотой', 'золотое', 'золотом']})
# ('кривой', {'count': 11, 'list': ['кривой', 'красивой']})
# ('получит', {'count': 11, 'list': ['получит', 'получишь', 'получить']})
# ('приветствовал', {'count': 11, 'list': ['приветствовал', 'приветствовать', 'приветствовали', 'приветствовала']})
# ('едет', {'count': 11, 'list': ['едет', 'ведет', 'уедет', 'поедет']})
# ('согласия', {'count': 11, 'list': ['согласия', 'согласился']})
# ('куда', {'count': 11, 'list': ['куда']})
# ('любил', {'count': 11, 'list': ['любил', 'любила', 'любили', 'полюбил']})
# ('закона', {'count': 11, 'list': ['закона', 'законах', 'законами']})
# ('вызов', {'count': 11, 'list': ['вызов', 'вызове', 'вызову', 'вызови']})
# ('дух', {'count': 11, 'list': ['дух', 'духу', 'духе', 'двух', 'духа']})
# ('вскочил', {'count': 11, 'list': ['вскочил', 'отскочил', 'вскочили']})
# ('стало', {'count': 11, 'list': ['стало', 'настало']})
# ('берег', {'count': 11, 'list': ['берег', 'берегу']})
# ('правил', {'count': 11, 'list': ['правил', 'правила', 'правильно']})
# ('сказать', {'count': 11, 'list': ['сказать']})
# ('шел', {'count': 11, 'list': ['шел', 'ушел', 'шелк']})
# ('биться', {'count': 11, 'list': ['биться', 'убедиться', 'браниться']})
# ('спутники', {'count': 11, 'list': ['спутники', 'спутниках', 'спутников', 'спутниками']})
# ('дочерью', {'count': 11, 'list': ['дочерью']})
# ('отправился', {'count': 10, 'list': ['отправился', 'отправиться', 'отправились']})
# ('скарпхедии', {'count': 10, 'list': ['скарпхедии', 'скарпхедина', 'скарпхедину', 'скарпхедином']})
# ('хедин', {'count': 10, 'list': ['хедин', 'хедина', 'хедином']})
# ('друзья', {'count': 10, 'list': ['друзья', 'друзьями']})
# ('снова', {'count': 10, 'list': ['снова']})
# ('стоял', {'count': 10, 'list': ['стоял', 'стояла', 'стояли']})
# ('сюда', {'count': 10, 'list': ['сюда', 'отсюда']})
# ('работа', {'count': 10, 'list': ['работа', 'работать', 'работает', 'поработай', 'работника']})
# ('через', {'count': 10, 'list': ['через']})
# ('свою', {'count': 10, 'list': ['свою']})
# ('под', {'count': 10, 'list': ['под']})
# ('уме', {'count': 10, 'list': ['уме', 'умер']})
# ('раны', {'count': 10, 'list': ['раны', 'равный', 'равных', 'страны']})
# ('недолго', {'count': 10, 'list': ['недолго', 'ненадолго']})
# ('пригласил', {'count': 10, 'list': ['пригласил', 'пригласили', 'пригласить', 'пригласила']})
# ('добавил', {'count': 10, 'list': ['добавил']})
# ('моего', {'count': 10, 'list': ['моего']})
# ('решит', {'count': 10, 'list': ['решит', 'решить', 'решите']})
# ('сколько', {'count': 10, 'list': ['сколько', 'несколько']})
# ('конечно', {'count': 10, 'list': ['конечно']})
# ('лодку', {'count': 10, 'list': ['лодку']})
# ('народ', {'count': 10, 'list': ['народ', 'народу']})
# ('асгрима', {'count': 10, 'list': ['асгрима', 'асгримом']})
# ('спроси', {'count': 10, 'list': ['спроси', 'спросит', 'спросив']})
# ('муж', {'count': 10, 'list': ['муж', 'мужа', 'муже', 'мужу']})
# ('всегда', {'count': 10, 'list': ['всегда']})
# ('ноге', {'count': 10, 'list': ['ноге', 'многие']})
# ('тех', {'count': 10, 'list': ['тех', 'трех']})
# ('хотя', {'count': 10, 'list': ['хотя', 'хотят']})
# ('весь', {'count': 10, 'list': ['весь', 'весть', 'вестью']})
# ('сварт', {'count': 10, 'list': ['сварт', 'сварта']})
# ('ночь', {'count': 10, 'list': ['ночь', 'ночью']})
# ('которые', {'count': 10, 'list': ['которые', 'которыми']})
# ('часто', {'count': 10, 'list': ['часто']})
# ('однако', {'count': 10, 'list': ['однако', 'одинаково']})
# ('вышли', {'count': 10, 'list': ['вышли']})
# ('эгмунд', {'count': 10, 'list': ['эгмунд', 'эгмунду', 'эгмунда']})
# ('такой', {'count': 10, 'list': ['такой']})
# ('сильный', {'count': 10, 'list': ['сильный']})
# ('свадьбу', {'count': 9, 'list': ['свадьбу']})
# ('бывал', {'count': 9, 'list': ['бывал', 'бывали', 'бывало']})
# ('землянку', {'count': 9, 'list': ['землянку']})
# ('нанес', {'count': 9, 'list': ['нанес']})
# ('почему', {'count': 9, 'list': ['почему']})
# ('откель', {'count': 9, 'list': ['откель']})
# ('серебра', {'count': 9, 'list': ['серебра']})
# ('мечом', {'count': 9, 'list': ['мечом']})
# ('наследство', {'count': 9, 'list': ['наследство']})
# ('исландии', {'count': 9, 'list': ['исландии']})
# ('попал', {'count': 9, 'list': ['попал', 'попало', 'попали', 'попадал', 'попался']})
# ('жизнь', {'count': 9, 'list': ['жизнь', 'жизнью']})
# ('исландию', {'count': 9, 'list': ['исландию']})
# ('ответили', {'count': 9, 'list': ['ответили']})
# ('моему', {'count': 9, 'list': ['моему']})
# ('свой', {'count': 9, 'list': ['свой']})
# ('землянке', {'count': 9, 'list': ['землянке']})
# ('домочадцы', {'count': 9, 'list': ['домочадцы', 'домочадцев', 'домочадцами']})
# ('добра', {'count': 9, 'list': ['добра', 'добрая']})
# ('плыл', {'count': 9, 'list': ['плыл', 'поплыл', 'уплыли', 'отплыл']})
# ('работник', {'count': 9, 'list': ['работник', 'работники', 'работников', 'работниками']})
# ('пошла', {'count': 9, 'list': ['пошла', 'прошла']})
# ('пришел', {'count': 9, 'list': ['пришел', 'пришелся', 'произошел']})
# ('мыс', {'count': 9, 'list': ['мыс', 'мыса', 'мысу']})
# ('кончился', {'count': 9, 'list': ['кончился', 'кончиться', 'кончилась', 'кончилось']})
# ('людям', {'count': 9, 'list': ['людям']})
# ('место', {'count': 9, 'list': ['место', 'место1']})
# ('деле', {'count': 9, 'list': ['деле', 'делает']})
# ('верх', {'count': 9, 'list': ['верх', 'сверх', 'вверх', 'сверху', 'верхом', 'дверях']})
# ('харальд', {'count': 9, 'list': ['харальд', 'харальда', 'харальдом']})
# ('секиру', {'count': 9, 'list': ['секиру']})
# ('дальше', {'count': 9, 'list': ['дальше']})
# ('торольвову', {'count': 9, 'list': ['торольвову', 'торольвовой']})
# ('нашли', {'count': 9, 'list': ['нашли']})
# ('вскоре', {'count': 9, 'list': ['вскоре']})
# ('можно', {'count': 9, 'list': ['можно']})
# ('назвал', {'count': 9, 'list': ['назвал']})
# ('женился', {'count': 9, 'list': ['женился', 'жениться']})
# ('никто', {'count': 9, 'list': ['никто']})
# ('лошадей', {'count': 9, 'list': ['лошадей']})
# ('разговаривал', {'count': 9, 'list': ['разговаривал', 'разговаривали']})
# ('медля', {'count': 8, 'list': ['медля', 'немедля']})
# ('волосы', {'count': 8, 'list': ['волосы']})
# ('рослый', {'count': 8, 'list': ['рослый']})
# ('показал', {'count': 8, 'list': ['показал', 'поскакал', 'отказали', 'оказался', 'показались', 'показалось']})
# ('обещал', {'count': 8, 'list': ['обещал', 'обещала', 'обещали', 'пообещала', 'пообещали']})
# ('проехал', {'count': 8, 'list': ['проехал', 'подъехал', 'проезжал', 'приехала', 'приехало']})
# ('отвел', {'count': 8, 'list': ['отвел', 'отвела', 'отвели', 'отвечал']})
# ('скажи', {'count': 8, 'list': ['скажи', 'скажись']})
# ('вел', {'count': 8, 'list': ['вел', 'вели', 'вела']})
# ('моя', {'count': 8, 'list': ['моя', 'моря']})
# ('глаз', {'count': 8, 'list': ['глаз', 'глаза', 'глазу']})
# ('скамье', {'count': 8, 'list': ['скамье']})
# ('стала', {'count': 8, 'list': ['стала', 'настала']})
# ('пришли', {'count': 8, 'list': ['пришли']})
# ('тоже', {'count': 8, 'list': ['тоже', 'строже']})
# ('сделали', {'count': 8, 'list': ['сделали', 'сделался']})
# ('пробыл', {'count': 8, 'list': ['пробыл', 'пробыли']})
# ('сделать', {'count': 8, 'list': ['сделать']})
# ('гости', {'count': 8, 'list': ['гости', 'гостил', 'гостит', 'гостить', 'гостишь']})
# ('хоть', {'count': 8, 'list': ['хоть']})
# ('пригорок', {'count': 8, 'list': ['пригорок']})
# ('подарки', {'count': 8, 'list': ['подарки', 'подарками']})
# ('отца', {'count': 8, 'list': ['отца']})
# ('пути', {'count': 8, 'list': ['пути', 'пустил']})
# ('твоя', {'count': 8, 'list': ['твоя']})
# ('сыновей', {'count': 8, 'list': ['сыновей']})
# ('одет', {'count': 8, 'list': ['одет', 'одета', 'одеты', 'одетых', 'пойдет', 'дойдет']})
# ('холм', {'count': 8, 'list': ['холм', 'холмы', 'холмов']})
# ('хакон', {'count': 8, 'list': ['хакон', 'хакона', 'хакону']})
# ('вызвал', {'count': 8, 'list': ['вызвал', 'вызвался']})
# ('сил', {'count': 8, 'list': ['сил', 'сила', 'силе', 'силу', 'силы']})
# ('бергторе', {'count': 8, 'list': ['бергторе']})
# ('поеду', {'count': 8, 'list': ['поеду', 'победу', 'поедут']})
# ('весной', {'count': 8, 'list': ['весной']})
# ('брак', {'count': 8, 'list': ['брак', 'брака']})
# ('поедешь', {'count': 8, 'list': ['поедешь', 'приедешь']})
# ('против', {'count': 8, 'list': ['против', 'напротив']})
# ('брани', {'count': 7, 'list': ['брани', 'бранила', 'бараний', 'бранись', 'бранить']})
# ('тови', {'count': 7, 'list': ['тови']})
# ('зовут', {'count': 7, 'list': ['зовут']})
# ('муки', {'count': 7, 'list': ['муки']})
# ('наступил', {'count': 7, 'list': ['наступил', 'наступило', 'наступила']})
# ('давно', {'count': 7, 'list': ['давно', 'недавно']})
# ('рассердился', {'count': 7, 'list': ['рассердился', 'рассердилась']})
# ('красы', {'count': 7, 'list': ['красы', 'красные', 'красоты', 'красных']})
# ('искусен', {'count': 7, 'list': ['искусен', 'искусный']})
# ('воли', {'count': 7, 'list': ['воли', 'вошли', 'вросли']})
# ('времени', {'count': 7, 'list': ['времени', 'временем', 'временами']})
# ('упустил', {'count': 7, 'list': ['упустил', 'спустили', 'испустил', 'отпустил', 'выпустил']})
# ('отбил', {'count': 7, 'list': ['отбил', 'отрубил']})
# ('принес', {'count': 7, 'list': ['принес', 'произнес', 'принесло', 'принесут', 'принесла', 'принесет']})
# ('одну', {'count': 7, 'list': ['одну', 'родину', 'одному']})
# ('назначь', {'count': 7, 'list': ['назначь', 'навзничь', 'назначить', 'назначать']})
# ('вдвоем', {'count': 7, 'list': ['вдвоем']})
# ('пить', {'count': 7, 'list': ['пить', 'выпить', 'купить']})
# ('места', {'count': 7, 'list': ['места', 'местах', 'местами']})
# ('одарил', {'count': 7, 'list': ['одарил', 'одарила', 'подарил']})
# ('хозяин', {'count': 7, 'list': ['хозяин', 'хозяина', 'хозяином']})
# ('жена', {'count': 7, 'list': ['жена', 'женаты']})
# ('поехала', {'count': 7, 'list': ['поехала', 'пожелала']})
# ('невесту', {'count': 7, 'list': ['невесту', 'невестой']})
# ('альтинг', {'count': 7, 'list': ['альтинг', 'альтинге', 'альтингом']})
# ('бросил', {'count': 7, 'list': ['бросил', 'бросили', 'забросил', 'набросил', 'бросились', 'бросилось']})
# ('ибо', {'count': 7, 'list': ['ибо', 'либо']})
# ('повтори', {'count': 7, 'list': ['повтори', 'поговори', 'повторили', 'повторить', 'повторится']})
# ('пожелал', {'count': 7, 'list': ['пожелал']})
# ('взять', {'count': 7, 'list': ['взять']})
# ('кроме', {'count': 7, 'list': ['кроме']})
# ('секира', {'count': 7, 'list': ['секира']})
# ('правнук', {'count': 7, 'list': ['правнук', 'правнука', 'правнучка', 'правнуком', 'правнучкой']})
# ('нравится', {'count': 7, 'list': ['нравится', 'понравится', 'понравиться']})
# ('утро', {'count': 7, 'list': ['утро', 'утром', 'устрой', 'наутро']})
# ('или', {'count': 7, 'list': ['или']})
# ('рано', {'count': 7, 'list': ['рано', 'равно', 'разном']})
# ('уговаривать', {'count': 7, 'list': ['уговаривать', 'выговаривать', 'разговаривать', 'договариваться']})
# ('ньяле', {'count': 7, 'list': ['ньяле', 'ньялем']})
# ('учтиво', {'count': 7, 'list': ['учтиво', 'учтивость']})
# ('однажды', {'count': 7, 'list': ['однажды']})
# ('конца', {'count': 7, 'list': ['конца']})
# ('халльгрим', {'count': 7, 'list': ['халльгрим', 'халльгрима', 'халльгримма']})
# ('думал', {'count': 7, 'list': ['думал', 'думали', 'обдумал', 'задумал']})
# ('заплати', {'count': 7, 'list': ['заплати', 'заплатил']})
# ('саге', {'count': 7, 'list': ['саге']})
# ('две', {'count': 7, 'list': ['две']})
# ('большую', {'count': 7, 'list': ['большую']})
# ('приехав', {'count': 7, 'list': ['приехав', 'приехать']})
# ('привез', {'count': 6, 'list': ['привез', 'привезет']})
# ('матери', {'count': 6, 'list': ['матери']})
# ('красивая', {'count': 6, 'list': ['красивая']})
# ('пронзил', {'count': 6, 'list': ['пронзил', 'проронил']})
# ('пролив', {'count': 6, 'list': ['пролив', 'проливе', 'пролива', 'прозорлив']})
# ('зачем', {'count': 6, 'list': ['зачем', 'незачем']})
# ('слыл', {'count': 6, 'list': ['слыл', 'слыла', 'слышал']})
# ('кому', {'count': 6, 'list': ['кому', 'некому', 'никому']})
# ('поплатится', {'count': 6, 'list': ['поплатится', 'поплатиться', 'поплатитесь', 'поплатишься']})
# ('разве', {'count': 6, 'list': ['разве', 'разводе']})
# ('клад', {'count': 6, 'list': ['клад', 'кладь', 'склада', 'заклад', 'кладью']})
# ('рану', {'count': 6, 'list': ['рану', 'рванул', 'ратную', 'траину']})
# ('гостей', {'count': 6, 'list': ['гостей']})
# ('лесной', {'count': 6, 'list': ['лесной']})
# ('ночи', {'count': 6, 'list': ['ночи', 'ночами']})
# ('возле', {'count': 6, 'list': ['возле']})
# ('отцу', {'count': 6, 'list': ['отцу']})
# ('рыжего', {'count': 6, 'list': ['рыжего']})
# ('про', {'count': 6, 'list': ['про', 'прок']})
# ('карл', {'count': 6, 'list': ['карл', 'карла']})
# ('вошел', {'count': 6, 'list': ['вошел']})
# ('дам', {'count': 6, 'list': ['дам']})
# ('этому', {'count': 6, 'list': ['этому', 'поэтому']})
# ('вира', {'count': 6, 'list': ['вира']})
# ('выдал', {'count': 6, 'list': ['выдал', 'выдался', 'выдавал']})
# ('случится', {'count': 6, 'list': ['случится', 'получится']})
# ('тихо', {'count': 6, 'list': ['тихо']})
# ('дымов', {'count': 6, 'list': ['дымов']})
# ('приданое', {'count': 6, 'list': ['приданое']})
# ('приходил', {'count': 6, 'list': ['приходил', 'приходило', 'приходились', 'приходилась', 'приходилось', 'происходило']})
# ('звать', {'count': 6, 'list': ['звать', 'назвать', 'вызвать']})
# ('заметил', {'count': 6, 'list': ['заметил', 'замедлил']})
# ('прежней', {'count': 6, 'list': ['прежней', 'прежнему']})
# ('двадцать', {'count': 6, 'list': ['двадцать', 'двенадцать']})
# ('пастух', {'count': 6, 'list': ['пастух', 'пастуху', 'пастуха']})
# ('одежду', {'count': 6, 'list': ['одежду']})
# ('навстречу', {'count': 6, 'list': ['навстречу']})
# ('пожалуй', {'count': 6, 'list': ['пожалуй', 'пожалуйста']})
# ('мужчин', {'count': 6, 'list': ['мужчин', 'мужчины', 'мужчина']})
# ('произошло', {'count': 6, 'list': ['произошло']})
# ('встал', {'count': 6, 'list': ['встал', 'встали']})
# ('условия', {'count': 6, 'list': ['условия', 'условием', 'условиях']})
# ('который', {'count': 6, 'list': ['который']})
# ('распоряжался', {'count': 6, 'list': ['распоряжался', 'распоряжаться', 'распоряжается', 'распоряжаешься']})
# ('даже', {'count': 6, 'list': ['даже']})
# ('сражался', {'count': 6, 'list': ['сражался', 'сражались', 'сражаться']})
# ('сидеть', {'count': 6, 'list': ['сидеть', 'усидеть']})
# ('обо', {'count': 6, 'list': ['обо']})
# ('отъезд', {'count': 6, 'list': ['отъезд', 'отъезде', 'отъезду', 'отъезда', 'отъездом']})
# ('вести', {'count': 6, 'list': ['вести', 'внести', 'двести']})
# ('строг', {'count': 6, 'list': ['строг', 'старого']})
# ('увидев', {'count': 6, 'list': ['увидев']})
# ('невеста', {'count': 6, 'list': ['невеста', 'невестами']})
# ('землю', {'count': 6, 'list': ['землю']})
# ('оставив', {'count': 6, 'list': ['оставив', 'оставить', 'доставил', 'составит']})
# ('дани', {'count': 6, 'list': ['дани', 'дании', 'данию', 'данией']})
# ('оставил', {'count': 6, 'list': ['оставил', 'выставил']})
# ('совсем', {'count': 6, 'list': ['совсем']})
# ('стоит', {'count': 6, 'list': ['стоит', 'стоите']})
# ('землянки', {'count': 6, 'list': ['землянки']})
# ('помогу', {'count': 6, 'list': ['помогу', 'подмогу']})
# ('скажет', {'count': 6, 'list': ['скажет']})
# ('подтверди', {'count': 6, 'list': ['подтверди', 'подтвердил', 'подтвердила', 'подтвердить', 'подтвердили', 'подтвердится']})
# ('оставит', {'count': 6, 'list': ['оставит', 'заставит', 'оставьте', 'доставить', 'остановит']})
# ('откеля', {'count': 6, 'list': ['откеля']})
# ('подарок', {'count': 6, 'list': ['подарок', 'подарков']})
# ('лишь', {'count': 5, 'list': ['лишь', 'любишь']})
# ('позвал', {'count': 5, 'list': ['позвал', 'позвала', 'подозвал', 'прозвали']})
# ('услышав', {'count': 5, 'list': ['услышав', 'услышала', 'услышать']})
# ('торхильд', {'count': 5, 'list': ['торхильд']})
# ('викинги', {'count': 5, 'list': ['викинги', 'викингов', 'викингский']})
# ('вольноотпущенником', {'count': 5, 'list': ['вольноотпущенником', 'вольноотпущенникова', 'вольноотпущенниковым']})
# ('аургоди', {'count': 5, 'list': ['аургоди']})
# ('ладно', {'count': 5, 'list': ['ладно']})
# ('ожидать', {'count': 5, 'list': ['ожидать', 'повидать']})
# ('пойди', {'count': 5, 'list': ['пойди', 'подойди']})
# ('ваше', {'count': 5, 'list': ['ваше', 'вашей', 'вашего', 'вашему']})
# ('конце', {'count': 5, 'list': ['конце']})
# ('мудр', {'count': 5, 'list': ['мудр', 'мудрая', 'мудрый']})
# ('должны', {'count': 5, 'list': ['должны']})
# ('назад', {'count': 5, 'list': ['назад']})
# ('примет', {'count': 5, 'list': ['примет', 'примете', 'придумает']})
# ('государь', {'count': 5, 'list': ['государь']})
# ('снял', {'count': 5, 'list': ['снял']})
# ('припасы', {'count': 5, 'list': ['припасы', 'припасов']})
# ('вик', {'count': 5, 'list': ['вик', 'вика']})
# ('повторю', {'count': 5, 'list': ['повторю', 'повторял', 'повторил']})
# ('стараться', {'count': 5, 'list': ['стараться', 'оставаться', 'встречаться', 'снаряжаться']})
# ('теплый', {'count': 5, 'list': ['теплый']})
# ('нашел', {'count': 5, 'list': ['нашел']})
# ('полу', {'count': 5, 'list': ['полу', 'получу', 'пользу']})
# ('девочка', {'count': 5, 'list': ['девочка', 'девочками']})
# ('дружинник', {'count': 5, 'list': ['дружинник', 'дружинники', 'дружинником']})
# ('переговоры', {'count': 5, 'list': ['переговоры', 'переговорах', 'переговорит']})
# ('домом', {'count': 5, 'list': ['домом']})
# ('мшистой', {'count': 5, 'list': ['мшистой']})
# ('эта', {'count': 5, 'list': ['эта']})
# ('уговорились', {'count': 5, 'list': ['уговорились', 'договорились']})
# ('которой', {'count': 5, 'list': ['которой']})
# ('завел', {'count': 5, 'list': ['завел', 'завела', 'завещал']})
# ('овец', {'count': 5, 'list': ['овец']})
# ('весна', {'count': 5, 'list': ['весна']})
# ('снарядил', {'count': 5, 'list': ['снарядил', 'снарядили', 'снарядились']})
# ('торхалла', {'count': 5, 'list': ['торхалла']})
# ('обычно', {'count': 5, 'list': ['обычно', 'обычного', 'необычно']})
# ('скрипица', {'count': 5, 'list': ['скрипица']})
# ('продолжала', {'count': 5, 'list': ['продолжала', 'продолжался', 'продолжалось', 'продолжалась']})
# ('нос', {'count': 5, 'list': ['нос', 'носа', 'носу']})
# ('распростертыми', {'count': 5, 'list': ['распростертыми']})
# ('обратно', {'count': 5, 'list': ['обратно', 'обратном']})
# ('пояс', {'count': 5, 'list': ['пояс', 'пояса', 'поясом']})
# ('платить', {'count': 5, 'list': ['платить', 'выплатить', 'заплатить']})
# ('ручей', {'count': 5, 'list': ['ручей']})
# ('принят', {'count': 5, 'list': ['принят', 'принять', 'принятые']})
# ('оставшись', {'count': 5, 'list': ['оставшись', 'оставались', 'остановись', 'постучавшись']})
# ('большой', {'count': 5, 'list': ['большой']})
# ('раги', {'count': 5, 'list': ['раги', 'браги']})
# ('рассуди', {'count': 5, 'list': ['рассуди', 'рассудил', 'рассадил', 'рассудить']})
# ('медведь', {'count': 5, 'list': ['медведь', 'медвежьи']})
# ('рядом', {'count': 5, 'list': ['рядом']})
# ('шла', {'count': 5, 'list': ['шла', 'ушла']})
# ('призвал', {'count': 5, 'list': ['призвал', 'призываю', 'привязал', 'призывая']})
# ('посредине', {'count': 5, 'list': ['посредине', 'посередине']})
# ('уплачена', {'count': 5, 'list': ['уплачена', 'заплачена']})
# ('можешь', {'count': 5, 'list': ['можешь']})
# ('упал', {'count': 5, 'list': ['упал']})
# ('скорее', {'count': 5, 'list': ['скорее']})
# ('добавив', {'count': 5, 'list': ['добавив', 'добавить', 'добавила']})
# ('передал', {'count': 5, 'list': ['передал', 'перевала', 'переехал', 'передала']})
# ('решение', {'count': 5, 'list': ['решение', 'решение4']})
# ('метнул', {'count': 5, 'list': ['метнул']})
# ('выплаты', {'count': 5, 'list': ['выплаты', 'выплатим', 'выплатил']})
# ('почти', {'count': 5, 'list': ['почти', 'почести']})
# ('твою', {'count': 5, 'list': ['твою']})
# ('должна', {'count': 5, 'list': ['должна']})
# ('торговый', {'count': 5, 'list': ['торговый']})
# ('свадьбы', {'count': 5, 'list': ['свадьбы']})
# ('пришлось', {'count': 5, 'list': ['пришлось', 'правилось']})
# ('берешься', {'count': 5, 'list': ['берешься', 'вернешься', 'доберешься']})
# ('посадил', {'count': 5, 'list': ['посадил', 'посадила', 'поставил', 'поладили']})
# ('другими', {'count': 5, 'list': ['другими']})
# ('вызываю', {'count': 5, 'list': ['вызываю', 'вызывать', 'вызывали']})
# ('соседей', {'count': 5, 'list': ['соседей', 'соседний']})
# ('немедленно', {'count': 5, 'list': ['немедленно', 'немедленной']})
# ('сполна', {'count': 5, 'list': ['сполна']})
# ('следовать', {'count': 5, 'list': ['следовать', 'беседовать', 'последовать']})
# ('вандиль', {'count': 5, 'list': ['вандиль']})
# ('ставлю', {'count': 5, 'list': ['ставлю', 'оставлю', 'доставлю']})
# ('сказав', {'count': 5, 'list': ['сказав']})
# ('сигурд', {'count': 5, 'list': ['сигурд', 'сигурда']})
# ('земли', {'count': 5, 'list': ['земли', 'землями']})
# ('кость', {'count': 5, 'list': ['кость']})
# ('быстро', {'count': 5, 'list': ['быстро']})
# ('девушка', {'count': 5, 'list': ['девушка', 'девушкой']})
# ('скажу', {'count': 5, 'list': ['скажу']})
# ('искать', {'count': 5, 'list': ['искать']})
# ('xxi', {'count': 5, 'list': ['xxi', 'xxvi', 'xxix', 'xxii', 'xxxi']})
# ('право', {'count': 5, 'list': ['право', 'правой', 'направо']})
# ('честь', {'count': 5, 'list': ['честь', 'честью']})
# ('едем', {'count': 5, 'list': ['едем', 'поедем']})
# ('запястье', {'count': 5, 'list': ['запястье']})
# ('бьёрна', {'count': 5, 'list': ['бьёрна']})
# ('родился', {'count': 5, 'list': ['родился', 'бросился', 'породнился']})
# ('кораблю', {'count': 5, 'list': ['кораблю']})
# ('видит', {'count': 5, 'list': ['видит', 'видите', 'увидит']})
# ('душе', {'count': 5, 'list': ['душе']})
# ('борт', {'count': 5, 'list': ['борт', 'борту']})
# ('легко', {'count': 5, 'list': ['легко', 'нелегко']})
# ('объятиями', {'count': 5, 'list': ['объятиями']})
# ('случай', {'count': 5, 'list': ['случай']})
# ('думаешь', {'count': 5, 'list': ['думаешь', 'надумаешь']})
# ('крови', {'count': 5, 'list': ['крови']})
# ('нашей', {'count': 5, 'list': ['нашей']})
# ('вижу', {'count': 5, 'list': ['вижу', 'увижу']})
# ('поход', {'count': 5, 'list': ['поход', 'похода', 'проход']})
# ('халльбьёрн', {'count': 5, 'list': ['халльбьёрн', 'халльбьёрна', 'халльбьёрну']})
# ('молчал', {'count': 5, 'list': ['молчал', 'молчалив']})
# ('ногу', {'count': 5, 'list': ['ногу']})
# ('гицур', {'count': 5, 'list': ['гицур', 'гицура', 'гицуром']})
# ('приходит', {'count': 5, 'list': ['приходит', 'переходит', 'приходится']})
# ('доволен', {'count': 5, 'list': ['доволен', 'довольны', 'довольна']})
# ('оползни', {'count': 5, 'list': ['оползни', 'оползнях']})
# ('подбить', {'count': 5, 'list': ['подбить', 'подарить', 'походить']})
# ('известно', {'count': 5, 'list': ['известно', 'известный']})
# ('жены', {'count': 5, 'list': ['жены']})
# ('воспитал', {'count': 5, 'list': ['воспитал', 'воспитывал', 'воспитателю', 'воспитатель', 'воспитателем']})
# ('всеми', {'count': 5, 'list': ['всеми']})
# ('сильно', {'count': 5, 'list': ['сильно', 'сильном']})
# ('привет', {'count': 5, 'list': ['привет', 'приветом', 'привести', 'приветлив']})
# ('думаю', {'count': 4, 'list': ['думаю', 'подумаю']})
# ('прочь', {'count': 4, 'list': ['прочь']})
# ('тяжел', {'count': 4, 'list': ['тяжел', 'тяжелый', 'тяжелым']})
# ('тейт', {'count': 4, 'list': ['тейт', 'тейта']})
# ('ламби', {'count': 4, 'list': ['ламби']})
# ('грудь', {'count': 4, 'list': ['грудь']})
# ('найдет', {'count': 4, 'list': ['найдет', 'найдется']})
# ('сена', {'count': 4, 'list': ['сена']})
# ('недостатки', {'count': 4, 'list': ['недостатки', 'недостатках']})
# ('жену', {'count': 4, 'list': ['жену']})
# ('вечером', {'count': 4, 'list': ['вечером']})
# ('защищайся', {'count': 4, 'list': ['защищайся', 'защищаться']})
# ('самое', {'count': 4, 'list': ['самое']})
# ('возьмет', {'count': 4, 'list': ['возьмет', 'возьмешь', 'возьмите']})
# ('держи', {'count': 4, 'list': ['держи', 'удержит', 'держишь', 'держись']})
# ('одной', {'count': 4, 'list': ['одной']})
# ('велика', {'count': 4, 'list': ['велика', 'невелика']})
# ('достигли', {'count': 4, 'list': ['достигли']})
# ('намерен', {'count': 4, 'list': ['намерен', 'надменен', 'намерении', 'намерениях']})
# ('согласие', {'count': 4, 'list': ['согласие', 'согласись', 'согласием']})
# ('отдал', {'count': 4, 'list': ['отдал', 'отдала']})
# ('поступки', {'count': 4, 'list': ['поступки', 'поступила']})
# ('счастья', {'count': 4, 'list': ['счастья', 'несчастья']})
# ('попроси', {'count': 4, 'list': ['попроси', 'попросить', 'попросится']})
# ('замахнулся', {'count': 4, 'list': ['замахнулся']})
# ('слушать', {'count': 4, 'list': ['слушать', 'выслушать']})
# ('согласен', {'count': 4, 'list': ['согласен']})
# ('горячего', {'count': 4, 'list': ['горячего']})
# ('равнине', {'count': 4, 'list': ['равнине']})
# ('голове', {'count': 4, 'list': ['голове']})
# ('нож', {'count': 4, 'list': ['нож']})
# ('свету', {'count': 4, 'list': ['свету', 'совету', 'советую']})
# ('насмешки', {'count': 4, 'list': ['насмешки', 'насмешлив']})
# ('возобновить', {'count': 4, 'list': ['возобновить', 'возобновлять']})
# ('кузнечный', {'count': 4, 'list': ['кузнечный']})
# ('заметив', {'count': 4, 'list': ['заметив', 'замертво', 'заметила']})
# ('поездке', {'count': 4, 'list': ['поездке', 'поединке']})
# ('впереди', {'count': 4, 'list': ['впереди']})
# ('торир', {'count': 4, 'list': ['торир', 'торира']})
# ('шли', {'count': 4, 'list': ['шли', 'ушли']})
# ('помолчав', {'count': 4, 'list': ['помолчав', 'промолчал']})
# ('поплыли', {'count': 4, 'list': ['поплыли']})
# ('друзей', {'count': 4, 'list': ['друзей']})
# ('ингьяльд', {'count': 4, 'list': ['ингьяльд', 'ингьяльда']})
# ('боевые', {'count': 4, 'list': ['боевые']})
# ('умный', {'count': 4, 'list': ['умный']})
# ('дошла', {'count': 4, 'list': ['дошла', 'подошла']})
# ('множество', {'count': 4, 'list': ['множество', 'множеством']})
# ('иск', {'count': 4, 'list': ['иск']})
# ('съестных', {'count': 4, 'list': ['съестных']})
# ('накидка', {'count': 4, 'list': ['накидка', 'накидкой', 'накликал']})
# ('нарушат', {'count': 4, 'list': ['нарушат', 'нарушила', 'нарушает', 'нарушали']})
# ('плащ', {'count': 4, 'list': ['плащ', 'плаще', 'плащом']})
# ('спустя', {'count': 4, 'list': ['спустя']})
# ('посмотри', {'count': 4, 'list': ['посмотри', 'посмотрит', 'присмотри', 'посмотрим']})
# ('каменистой', {'count': 4, 'list': ['каменистой']})
# ('силой', {'count': 4, 'list': ['силой']})
# ('повторять', {'count': 4, 'list': ['повторять', 'повторялось']})
# ('рукам', {'count': 4, 'list': ['рукам', 'руками', 'рукавом']})
# ('поездок', {'count': 4, 'list': ['поездок', 'поединок']})
# ('таким', {'count': 4, 'list': ['таким', 'такими']})
# ('проснулся', {'count': 4, 'list': ['проснулся', 'проснулись', 'промахнулся']})
# ('продать', {'count': 4, 'list': ['продать', 'пировать', 'поведать']})
# ('готов', {'count': 4, 'list': ['готов', 'готовы']})
# ('говоря', {'count': 4, 'list': ['говоря', 'говорят']})
# ('знать', {'count': 4, 'list': ['знать', 'узнать']})
# ('помощи', {'count': 4, 'list': ['помощи', 'помощник']})
# ('широком', {'count': 4, 'list': ['широком', 'широкого']})
# ('богатство', {'count': 4, 'list': ['богатство']})
# ('счастливы', {'count': 4, 'list': ['счастливы', 'счастливого']})
# ('раннвейг', {'count': 4, 'list': ['раннвейг']})
# ('награду', {'count': 4, 'list': ['награду', 'наградит']})
# ('воина', {'count': 4, 'list': ['воина', 'воинами']})
# ('меньше', {'count': 4, 'list': ['меньше']})
# ('собралось', {'count': 4, 'list': ['собралось', 'собирались']})
# ('честолюбия', {'count': 4, 'list': ['честолюбия', 'честолюбивым']})
# ('трус', {'count': 4, 'list': ['трус', 'трусы', 'труса', 'трусом']})
# ('обулся', {'count': 4, 'list': ['обулся', 'обернулся', 'обручился']})
# ('окончит', {'count': 4, 'list': ['окончит', 'кончится']})
# ('смерти', {'count': 4, 'list': ['смерти']})
# ('бороды', {'count': 4, 'list': ['бороды', 'бородатый']})
# ('свадебном', {'count': 4, 'list': ['свадебном', 'свадебного', 'свадебному']})
# ('братьев', {'count': 4, 'list': ['братьев']})
# ('продал', {'count': 4, 'list': ['продал', 'прождал', 'продолжал']})
# ('провел', {'count': 4, 'list': ['провел', 'провели']})
# ('уплати', {'count': 4, 'list': ['уплати', 'уплатил']})
# ('копья', {'count': 4, 'list': ['копья']})
# ('гейр', {'count': 4, 'list': ['гейр', 'гейра']})
# ('казалось', {'count': 4, 'list': ['казалось', 'оказалось']})
# ('сотню', {'count': 4, 'list': ['сотню']})
# ('посетить', {'count': 4, 'list': ['посетить', 'погостить', 'пакостить']})
# ('должно', {'count': 4, 'list': ['должно']})
# ('речь', {'count': 4, 'list': ['речь']})
# ('согласии', {'count': 4, 'list': ['согласии', 'согласились']})
# ('раньше', {'count': 4, 'list': ['раньше']})
# ('советовал', {'count': 4, 'list': ['советовал', 'посоветовал', 'отсоветовали']})
# ('радушно', {'count': 4, 'list': ['радушно']})
# ('лугу', {'count': 4, 'list': ['лугу', 'слугу']})
# ('приготовил', {'count': 4, 'list': ['приготовил', 'приготовимся', 'приготовился', 'приготовились']})
# ('коли', {'count': 4, 'list': ['коли', 'колени']})
# ('спокойно', {'count': 4, 'list': ['спокойно', 'спокойный', 'неспокойно']})
# ('вид', {'count': 4, 'list': ['вид', 'виду']})
# ('хамунд', {'count': 4, 'list': ['хамунд', 'хамунда']})
# ('всадил', {'count': 4, 'list': ['всадил', 'высадили', 'высадился']})
# ('сегодня', {'count': 4, 'list': ['сегодня']})
# ('стола', {'count': 4, 'list': ['стола', 'столбам']})
# ('дружба', {'count': 4, 'list': ['дружба']})
# ('лососей', {'count': 4, 'list': ['лососей', 'лососьей']})
# ('сигвата', {'count': 4, 'list': ['сигвата', 'сигхвата']})
# ('дорогу', {'count': 4, 'list': ['дорогу']})
# ('исландец', {'count': 4, 'list': ['исландец', 'исландцев']})
# ('поселился', {'count': 4, 'list': ['поселился', 'поселилась', 'переселился']})
# ('нарядно', {'count': 4, 'list': ['нарядно', 'нарядных', 'нарядная', 'нарядней']})
# ('обращал', {'count': 4, 'list': ['обращал', 'обращать', 'обращался']})
# ('будто', {'count': 4, 'list': ['будто']})
# ('желаю', {'count': 4, 'list': ['желаю', 'желанию']})
# ('случае', {'count': 4, 'list': ['случае']})
# ('прозванию', {'count': 4, 'list': ['прозванию', 'прозванием']})
# ('новость', {'count': 4, 'list': ['новость', 'новостью', 'новостях']})
# ...
# ('скалу', {'count': 1, 'list': ['скалу']})
# ('впустил', {'count': 1, 'list': ['впустил']})
# ('отбавляй', {'count': 1, 'list': ['отбавляй']})
# ('обвила', {'count': 1, 'list': ['обвила']})
# ('ладите', {'count': 1, 'list': ['ладите']})
# ('синих', {'count': 1, 'list': ['синих']})
# ('обмана', {'count': 1, 'list': ['обмана']})
# ('стоящее', {'count': 1, 'list': ['стоящее']})
# ('болото', {'count': 1, 'list': ['болото']})
# ('нагнав', {'count': 1, 'list': ['нагнав']})
# ('ловлю', {'count': 1, 'list': ['ловлю']})
# ('пояском', {'count': 1, 'list': ['пояском']})
# ('заводил', {'count': 1, 'list': ['заводил']})
# ('проделку', {'count': 1, 'list': ['проделку']})
# ('бондов', {'count': 1, 'list': ['бондов']})
# ('ребенком', {'count': 1, 'list': ['ребенком']})
# ('присутствующие', {'count': 1, 'list': ['присутствующие']})
# ('зайдет', {'count': 1, 'list': ['зайдет']})
# ('повязку', {'count': 1, 'list': ['повязку']})
# ('неотомщенным', {'count': 1, 'list': ['неотомщенным']})
# ('открыл', {'count': 1, 'list': ['открыл']})
# ('дав', {'count': 1, 'list': ['дав']})
# ('погубит', {'count': 1, 'list': ['погубит']})
# ('ожидали', {'count': 1, 'list': ['ожидали']})
# ('опаснее', {'count': 1, 'list': ['опаснее']})
# ('неполадлив', {'count': 1, 'list': ['неполадлив']})
# ('козла', {'count': 1, 'list': ['козла']})
# ('лежавший', {'count': 1, 'list': ['лежавший']})
# ('уроном', {'count': 1, 'list': ['уроном']})
# ('стеснения', {'count': 1, 'list': ['стеснения']})
# ('скарпхедип', {'count': 1, 'list': ['скарпхедип']})
# ('первый', {'count': 1, 'list': ['первый']})
# ('менее', {'count': 1, 'list': ['менее']})
# ('возмущен', {'count': 1, 'list': ['возмущен']})
# ('датским', {'count': 1, 'list': ['датским']})
# ('торкатла', {'count': 1, 'list': ['торкатла']})
# ('выданье', {'count': 1, 'list': ['выданье']})
# ('выслушаны', {'count': 1, 'list': ['выслушаны']})
# ('выгрузкой', {'count': 1, 'list': ['выгрузкой']})
# ('надлежало', {'count': 1, 'list': ['надлежало']})
# ('захочется', {'count': 1, 'list': ['захочется']})
# ('встретила', {'count': 1, 'list': ['встретила']})
# ('смолкли', {'count': 1, 'list': ['смолкли']})
# ('выбраться', {'count': 1, 'list': ['выбраться']})
# ('умирать', {'count': 1, 'list': ['умирать']})
# ('покрылись', {'count': 1, 'list': ['покрылись']})
# ('посовещались', {'count': 1, 'list': ['посовещались']})
# ('расстанемся', {'count': 1, 'list': ['расстанемся']})
# ('отложить', {'count': 1, 'list': ['отложить']})
# ('старухе', {'count': 1, 'list': ['старухе']})
# ('хейдабёр', {'count': 1, 'list': ['хейдабёр']})
# ('девушек', {'count': 1, 'list': ['девушек']})
# ('дворами', {'count': 1, 'list': ['дворами']})
# ('волю', {'count': 1, 'list': ['волю']})
# ('супружеская', {'count': 1, 'list': ['супружеская']})
# ('припомним', {'count': 1, 'list': ['припомним']})
# ('обижен', {'count': 1, 'list': ['обижен']})
# ('золотые', {'count': 1, 'list': ['золотые']})
# ('поживиться', {'count': 1, 'list': ['поживиться']})
# ('губу', {'count': 1, 'list': ['губу']})
# ('потекла', {'count': 1, 'list': ['потекла']})
# ('тесьмой', {'count': 1, 'list': ['тесьмой']})
# ('дозорный', {'count': 1, 'list': ['дозорный']})
# ('чужим', {'count': 1, 'list': ['чужим']})
# ('веслах', {'count': 1, 'list': ['веслах']})
# ('вгляделись', {'count': 1, 'list': ['вгляделись']})
# ('увеличиться', {'count': 1, 'list': ['увеличиться']})
# ('сыщется', {'count': 1, 'list': ['сыщется']})
# ('отомстят', {'count': 1, 'list': ['отомстят']})
# ('никак', {'count': 1, 'list': ['никак']})
# ('дня', {'count': 1, 'list': ['дня']})
# ('захваченное', {'count': 1, 'list': ['захваченное']})
# ('воротишь', {'count': 1, 'list': ['воротишь']})
# ('вспыльчивого', {'count': 1, 'list': ['вспыльчивого']})
# ('невесты', {'count': 1, 'list': ['невесты']})
# ('однаджы', {'count': 1, 'list': ['однаджы']})
# ('красоту', {'count': 1, 'list': ['красоту']})
# ('смягчает', {'count': 1, 'list': ['смягчает']})
# ('неодобрением', {'count': 1, 'list': ['неодобрением']})
# ('щитом', {'count': 1, 'list': ['щитом']})
# ('посчитаемся', {'count': 1, 'list': ['посчитаемся']})
# ('набрать', {'count': 1, 'list': ['набрать']})
# ('помешать', {'count': 1, 'list': ['помешать']})
# ('краю', {'count': 1, 'list': ['краю']})
# ('передышку', {'count': 1, 'list': ['передышку']})
# ('окажем', {'count': 1, 'list': ['окажем']})
# ('мужем', {'count': 1, 'list': ['мужем']})
# ('подносили', {'count': 1, 'list': ['подносили']})
# ('ответный', {'count': 1, 'list': ['ответный']})
# ('вашим', {'count': 1, 'list': ['вашим']})
# ('благородно', {'count': 1, 'list': ['благородно']})
# ('наука', {'count': 1, 'list': ['наука']})
# ('великим', {'count': 1, 'list': ['великим']})
# ('общее', {'count': 1, 'list': ['общее']})
# ('обернуться', {'count': 1, 'list': ['обернуться']})
# ('спорить', {'count': 1, 'list': ['спорить']})
# ('печешься', {'count': 1, 'list': ['печешься']})
# ('ближайшего', {'count': 1, 'list': ['ближайшего']})
# ('подружится', {'count': 1, 'list': ['подружится']})
# ('зевота', {'count': 1, 'list': ['зевота']})
# ('белую', {'count': 1, 'list': ['белую']})
# ('рьяно', {'count': 1, 'list': ['рьяно']})
# ('отнеслись', {'count': 1, 'list': ['отнеслись']})
# ('недели', {'count': 1, 'list': ['недели']})
# ('иметь', {'count': 1, 'list': ['иметь']})
# ('произведен', {'count': 1, 'list': ['произведен']})
# ('приглядывать', {'count': 1, 'list': ['приглядывать']})
# ('супружеского', {'count': 1, 'list': ['супружеского']})
# ('типга', {'count': 1, 'list': ['типга']})
# ('двери', {'count': 1, 'list': ['двери']})
# ('озера', {'count': 1, 'list': ['озера']})
# ('бой', {'count': 1, 'list': ['бой']})
# ('порастеряли', {'count': 1, 'list': ['порастеряли']})
# ('поддержать', {'count': 1, 'list': ['поддержать']})
# ('завязалось', {'count': 1, 'list': ['завязалось']})
# ('проклинали', {'count': 1, 'list': ['проклинали']})
# ('особенными', {'count': 1, 'list': ['особенными']})
# ('ровня', {'count': 1, 'list': ['ровня']})
# ('норвежец', {'count': 1, 'list': ['норвежец']})
# ('старый', {'count': 1, 'list': ['старый']})
# ('добьешься', {'count': 1, 'list': ['добьешься']})
# ('округе', {'count': 1, 'list': ['округе']})
# ('какие', {'count': 1, 'list': ['какие']})
# ('нагрянь', {'count': 1, 'list': ['нагрянь']})
# ('согласию', {'count': 1, 'list': ['согласию']})
# ('годен', {'count': 1, 'list': ['годен']})
# ('стейнгримова', {'count': 1, 'list': ['стейнгримова']})
# ('северной', {'count': 1, 'list': ['северной']})
# ('промаха', {'count': 1, 'list': ['промаха']})
# ('воткнутое', {'count': 1, 'list': ['воткнутое']})
# ('уснул', {'count': 1, 'list': ['уснул']})
# ('мстят', {'count': 1, 'list': ['мстят']})
# ('ловкостью', {'count': 1, 'list': ['ловкостью']})
# ('рот', {'count': 1, 'list': ['рот']})
# ('домашними', {'count': 1, 'list': ['домашними']})
# ('скрыта', {'count': 1, 'list': ['скрыта']})
# ('подвигом', {'count': 1, 'list': ['подвигом']})
# ('андотта', {'count': 1, 'list': ['андотта']})
# ('колена', {'count': 1, 'list': ['колена']})
# ('прошлым', {'count': 1, 'list': ['прошлым']})
# ('лоб', {'count': 1, 'list': ['лоб']})
# ('вскружила', {'count': 1, 'list': ['вскружила']})
# ('фарерского', {'count': 1, 'list': ['фарерского']})
# ('победы', {'count': 1, 'list': ['победы']})
# ('застлал', {'count': 1, 'list': ['застлал']})
# ('боялись', {'count': 1, 'list': ['боялись']})
# ('пришлю', {'count': 1, 'list': ['пришлю']})
# ('видишь', {'count': 1, 'list': ['видишь']})
# ('неясно', {'count': 1, 'list': ['неясно']})
# ('подходил', {'count': 1, 'list': ['подходил']})
# ('мшистая', {'count': 1, 'list': ['мшистая']})
# ('впоследствии', {'count': 1, 'list': ['впоследствии']})
# ('обратится', {'count': 1, 'list': ['обратится']})
# ('общий', {'count': 1, 'list': ['общий']})
# ('изгонит', {'count': 1, 'list': ['изгонит']})
# ('красную', {'count': 1, 'list': ['красную']})
# ('ивара', {'count': 1, 'list': ['ивара']})
# ('сон', {'count': 1, 'list': ['сон']})
# ('приветливы', {'count': 1, 'list': ['приветливы']})
# ('объехал', {'count': 1, 'list': ['объехал']})
# ('помочь', {'count': 1, 'list': ['помочь']})
# ('приготовления', {'count': 1, 'list': ['приготовления']})
# ('приглашаю', {'count': 1, 'list': ['приглашаю']})
# ('горах', {'count': 1, 'list': ['горах']})
# ('кружевом', {'count': 1, 'list': ['кружевом']})
# ('довольный', {'count': 1, 'list': ['довольный']})
# ('переживу', {'count': 1, 'list': ['переживу']})
# ('решении', {'count': 1, 'list': ['решении']})
# ('хрёрека', {'count': 1, 'list': ['хрёрека']})
# ('знатоков', {'count': 1, 'list': ['знатоков']})
# ('сутки', {'count': 1, 'list': ['сутки']})
# ('отнимет', {'count': 1, 'list': ['отнимет']})
# ('таков', {'count': 1, 'list': ['таков']})
# ('кольбейн', {'count': 1, 'list': ['кольбейн']})
# ('пятнадцать', {'count': 1, 'list': ['пятнадцать']})
# ('голубые', {'count': 1, 'list': ['голубые']})
# ('величайшим', {'count': 1, 'list': ['величайшим']})
# ('учтивая', {'count': 1, 'list': ['учтивая']})
# ('длинноногой', {'count': 1, 'list': ['длинноногой']})
# ('довелось', {'count': 1, 'list': ['довелось']})
# ('скверное', {'count': 1, 'list': ['скверное']})
# ('тяжким', {'count': 1, 'list': ['тяжким']})
# ('всеобщим', {'count': 1, 'list': ['всеобщим']})
# ('дождь', {'count': 1, 'list': ['дождь']})
# ('встречного', {'count': 1, 'list': ['встречного']})
# ('закусив', {'count': 1, 'list': ['закусив']})
# ('стейнгримову', {'count': 1, 'list': ['стейнгримову']})
# ('задирать', {'count': 1, 'list': ['задирать']})
# ('погибнуть', {'count': 1, 'list': ['погибнуть']})
# ('разбудил', {'count': 1, 'list': ['разбудил']})
# ('наследники', {'count': 1, 'list': ['наследники']})
# ('знатные', {'count': 1, 'list': ['знатные']})
# ('растащили', {'count': 1, 'list': ['растащили']})
# ('спасаться', {'count': 1, 'list': ['спасаться']})
# ('зима', {'count': 1, 'list': ['зима']})
# ('сдамся', {'count': 1, 'list': ['сдамся']})
# ('незаконными', {'count': 1, 'list': ['незаконными']})
# ('былой', {'count': 1, 'list': ['былой']})
# ('кровоподтек', {'count': 1, 'list': ['кровоподтек']})
# ('блестели', {'count': 1, 'list': ['блестели']})
# ('выронил', {'count': 1, 'list': ['выронил']})
# ('поцеловал', {'count': 1, 'list': ['поцеловал']})
# ('беседовал', {'count': 1, 'list': ['беседовал']})
# ('отняла', {'count': 1, 'list': ['отняла']})
# ('росту', {'count': 1, 'list': ['росту']})
# ('надеюсь', {'count': 1, 'list': ['надеюсь']})
# ('имя', {'count': 1, 'list': ['имя']})
# ('короче', {'count': 1, 'list': ['короче']})
# ('дружбы', {'count': 1, 'list': ['дружбы']})
# ('дернул', {'count': 1, 'list': ['дернул']})
# ('заботы', {'count': 1, 'list': ['заботы']})
# ('каменную', {'count': 1, 'list': ['каменную']})
# ('напав', {'count': 1, 'list': ['напав']})
# ('судьбы', {'count': 1, 'list': ['судьбы']})
# ('призовешь', {'count': 1, 'list': ['призовешь']})
# ('длинноногую', {'count': 1, 'list': ['длинноногую']})
# ('завладеют', {'count': 1, 'list': ['завладеют']})
# ('крупные', {'count': 1, 'list': ['крупные']})
# ('уйдешь', {'count': 1, 'list': ['уйдешь']})
# ('скамьях', {'count': 1, 'list': ['скамьях']})
# ('кожаном', {'count': 1, 'list': ['кожаном']})
# ('поплатимся', {'count': 1, 'list': ['поплатимся']})
# ('искушений', {'count': 1, 'list': ['искушений']})
# ('обменялся', {'count': 1, 'list': ['обменялся']})
# ('шапку', {'count': 1, 'list': ['шапку']})
# ('выйдя', {'count': 1, 'list': ['выйдя']})
# ('кожу', {'count': 1, 'list': ['кожу']})
# ('рассек', {'count': 1, 'list': ['рассек']})
# ('плавании', {'count': 1, 'list': ['плавании']})
# ('заехали', {'count': 1, 'list': ['заехали']})
# ('сведущим', {'count': 1, 'list': ['сведущим']})
# ('умным', {'count': 1, 'list': ['умным']})
# ('распорядится', {'count': 1, 'list': ['распорядится']})
# ('предостерегать', {'count': 1, 'list': ['предостерегать']})
# ('сменились', {'count': 1, 'list': ['сменились']})
# ('вооружаться', {'count': 1, 'list': ['вооружаться']})
# ('получается', {'count': 1, 'list': ['получается']})
# ('летевшее', {'count': 1, 'list': ['летевшее']})
# ('новости', {'count': 1, 'list': ['новости']})
# ('занимались', {'count': 1, 'list': ['занимались']})
# ('адальстейна', {'count': 1, 'list': ['адальстейна']})
# ('сочли', {'count': 1, 'list': ['сочли']})
# ('сестра', {'count': 1, 'list': ['сестра']})
# ('бледное', {'count': 1, 'list': ['бледное']})
# ('укрыли', {'count': 1, 'list': ['укрыли']})
# ('ошибаешься', {'count': 1, 'list': ['ошибаешься']})
# ('идя', {'count': 1, 'list': ['идя']})
# ('опустив', {'count': 1, 'list': ['опустив']})
# ('близкими', {'count': 1, 'list': ['близкими']})
# ('дядю', {'count': 1, 'list': ['дядю']})
# ('цели', {'count': 1, 'list': ['цели']})
# ('родней', {'count': 1, 'list': ['родней']})
# ('неуступчив', {'count': 1, 'list': ['неуступчив']})
# ('имеешь', {'count': 1, 'list': ['имеешь']})
# ('наконечником', {'count': 1, 'list': ['наконечником']})
# ('давал', {'count': 1, 'list': ['давал']})
# ('отлеживаться', {'count': 1, 'list': ['отлеживаться']})
# ('подбила', {'count': 1, 'list': ['подбила']})
# ('спины', {'count': 1, 'list': ['спины']})
# ('продолжали', {'count': 1, 'list': ['продолжали']})
# ('познакомил', {'count': 1, 'list': ['познакомил']})
# ('гримова', {'count': 1, 'list': ['гримова']})
# ('смотришь', {'count': 1, 'list': ['смотришь']})
# ('дверь', {'count': 1, 'list': ['дверь']})
# ('предводитель', {'count': 1, 'list': ['предводитель']})
# ('лишил', {'count': 1, 'list': ['лишил']})
# ('увели', {'count': 1, 'list': ['увели']})
# ('ворона', {'count': 1, 'list': ['ворона']})
# ('прекраснейшим', {'count': 1, 'list': ['прекраснейшим']})
# ('застрявшим', {'count': 1, 'list': ['застрявшим']})
# ('усмехнулся', {'count': 1, 'list': ['усмехнулся']})
# ('толком', {'count': 1, 'list': ['толком']})
# ('товарами', {'count': 1, 'list': ['товарами']})
# ('десять', {'count': 1, 'list': ['десять']})
# ('поостеречься', {'count': 1, 'list': ['поостеречься']})
# ('наследница', {'count': 1, 'list': ['наследница']})
# ('жадности', {'count': 1, 'list': ['жадности']})
# ('повела', {'count': 1, 'list': ['повела']})
# ('смаланд', {'count': 1, 'list': ['смаланд']})
# ('выйдешь', {'count': 1, 'list': ['выйдешь']})
# ('широким', {'count': 1, 'list': ['широким']})
# ('овчин', {'count': 1, 'list': ['овчин']})
# ('аскеля', {'count': 1, 'list': ['аскеля']})
# ('разбираюсь', {'count': 1, 'list': ['разбираюсь']})
# ('сватовства', {'count': 1, 'list': ['сватовства']})
# ('напоминало', {'count': 1, 'list': ['напоминало']})
# ('обеих', {'count': 1, 'list': ['обеих']})
# ('усмехаясь', {'count': 1, 'list': ['усмехаясь']})
# ('мягкий', {'count': 1, 'list': ['мягкий']})
# ('созывать', {'count': 1, 'list': ['созывать']})
# ('придумай', {'count': 1, 'list': ['придумай']})
# ('потерей', {'count': 1, 'list': ['потерей']})
# ('угодил', {'count': 1, 'list': ['угодил']})
# ('нелады', {'count': 1, 'list': ['нелады']})
# ('приобретателя', {'count': 1, 'list': ['приобретателя']})
# ('зовется', {'count': 1, 'list': ['зовется']})
# ('порасспроси', {'count': 1, 'list': ['порасспроси']})
# ('поменяться', {'count': 1, 'list': ['поменяться']})
# ('наймом', {'count': 1, 'list': ['наймом']})
# ('северные', {'count': 1, 'list': ['северные']})
# ('расходовала', {'count': 1, 'list': ['расходовала']})
# ('вплотную', {'count': 1, 'list': ['вплотную']})
# ('дружину', {'count': 1, 'list': ['дружину']})
# ('заснут', {'count': 1, 'list': ['заснут']})
# ('выпадет', {'count': 1, 'list': ['выпадет']})
# ('древки', {'count': 1, 'list': ['древки']})
# ('безрассудная', {'count': 1, 'list': ['безрассудная']})
# ('выступил', {'count': 1, 'list': ['выступил']})
# ('видывал', {'count': 1, 'list': ['видывал']})
# ('таскаться', {'count': 1, 'list': ['таскаться']})
# ('возражают', {'count': 1, 'list': ['возражают']})
# ('побудило', {'count': 1, 'list': ['побудило']})
# ('правильным', {'count': 1, 'list': ['правильным']})
# ('пригласит', {'count': 1, 'list': ['пригласит']})
# ('торкель', {'count': 1, 'list': ['торкель']})
# ('кровавая', {'count': 1, 'list': ['кровавая']})
# ('нехорошо', {'count': 1, 'list': ['нехорошо']})
# ('дожидаясь', {'count': 1, 'list': ['дожидаясь']})
# ('щедр', {'count': 1, 'list': ['щедр']})
# ('разглядывать', {'count': 1, 'list': ['разглядывать']})
# ('вкатили', {'count': 1, 'list': ['вкатили']})
# ('спешился', {'count': 1, 'list': ['спешился']})
# ('малый', {'count': 1, 'list': ['малый']})
# ('присмотрел', {'count': 1, 'list': ['присмотрел']})
# ('бауга', {'count': 1, 'list': ['бауга']})
# ('приближается', {'count': 1, 'list': ['приближается']})
# ('ирландцем', {'count': 1, 'list': ['ирландцем']})
# ('серебро', {'count': 1, 'list': ['серебро']})
# ('перепрыгнул', {'count': 1, 'list': ['перепрыгнул']})
# ('голльнир', {'count': 1, 'list': ['голльнир']})
# ('странными', {'count': 1, 'list': ['странными']})
